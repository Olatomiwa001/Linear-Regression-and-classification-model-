# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
df = pd.read_csv('house_prices.csv')

# %%
# Display first 5 rows
df.head(20)
# Out:
#     House_ID  Square_Feet  Bedrooms  Age   Price
# 0          1         1660         5   48  408062
# 1          2         4572         5   23  482986
# 2          3         3892         5    6   75457
# 3          4         1266         1   13  383811
# 4          5         4244         1   49  402895
# 5          6         3971         5   23  112894
# 6          7         3719         1    9  111305
# 7          8          930         4   17  193684
# 8          9         2485         5    2  283913
# 9         10         1569         1   19  259699
# 10        11         3191         2   19  480305
# 11        12         3233         5    7  364281
# 12        13         1984         5   42   50559
# 13        14         4185         4   42  378393
# 14        15         4917         3   20   87361
# 15        16         3704         3    9  392864
# 16        17         1274         4   17  327405
# 17        18         1882         4   27  332516
# 18        19         3358         4   47  367499
# 19        20         2847         3    2  278748

# %%
df.isnull().sum()
# Out:
# House_ID       0
# Square_Feet    0
# Bedrooms       0
# Age            0
# Price          0
# dtype: int64

# %%
df.describe()
# Out:
#           House_ID  Square_Feet     Bedrooms          Age          Price
# count  3000.000000  3000.000000  3000.000000  3000.000000    3000.000000
# mean   1500.500000  2943.929000     3.005333    24.727667  274817.961667
# std     866.169729  1200.752576     1.417265    14.070827  127460.378815
# min       1.000000   801.000000     1.000000     1.000000   50036.000000
# 25%     750.750000  1890.500000     2.000000    13.000000  165239.250000
# 50%    1500.500000  2951.000000     3.000000    25.000000  278809.000000
# 75%    2250.250000  3991.000000     4.000000    37.000000  382872.250000
# max    3000.000000  4999.000000     5.000000    49.000000  499732.000000

# %%
sns.pairplot(df, diag_kind='kde')
plt.show()

# %%
#  define features(x) and target variable(Y)
x = df[['Square_Feet', 'Bedrooms', 'Age']]
y = df['Price']

# %%
# Split data into training and testing 
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

# %%
print(f"Mean Absolute Error: {mae}")
print(f"Mean squared Error: {mse}")
# Out:
# Mean Absolute Error: 106061.55175062308
# Mean squared Error: 15588425099.575834

# %%
plt.scatter(y_test, y_pred, alpha=0.5, color='Blue')
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual vs. Predicted House Prices")
plt.show()
